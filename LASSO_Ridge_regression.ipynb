# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeRegressor

# %%
load_boston = load_boston()

# %%
df = pd.DataFrame(load_boston.data, columns=load_boston.feature_names)

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
y = pd.DataFrame(load_boston.target, columns=['target'])

# %%
y.head()
# Out:
#    target
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2

# %%
df.isnull().count()
# Out:
# CRIM       506
# ZN         506
# INDUS      506
# CHAS       506
# NOX        506
# RM         506
# AGE        506
# DIS        506
# RAD        506
# TAX        506
# PTRATIO    506
# B          506
# LSTAT      506
# dtype: int64

# %%
df.shape
# Out:
# (506, 13)

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT
# count  506.000000
# mean    12.653063
# std      7.141062
# min      1.730000
# 25%      6.950000
# 50%     11.360000
# 75%     16.955000
# max     37.970000

# %%
df['CRIM'] = np.log(df['CRIM'])
df['TAX'] = np.log(df['TAX'])

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    -0.780436   11.363636   11.136779    0.069170    0.554695    6.284634
# std      2.162050   23.322453    6.860353    0.253994    0.115878    0.702617
# min     -5.064036    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%     -2.500488    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%     -1.360641    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      1.302119   12.500000   18.100000    0.000000    0.624000    6.623500
# max      4.488369  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407    5.931405   18.455534  356.674032
# std     28.148861    2.105710    8.707259    0.396367    2.164946   91.294864
# min      2.900000    1.129600    1.000000    5.231109   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000    5.631212   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000    5.799093   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000    6.501290   20.200000  396.225000
# max    100.000000   12.126500   24.000000    6.566672   22.000000  396.900000
#
#             LSTAT
# count  506.000000
# mean    12.653063
# std      7.141062
# min      1.730000
# 25%      6.950000
# 50%     11.360000
# 75%     16.955000
# max     37.970000

# %%
x_train, x_test, y_train, y_test = train_test_split(df, y, test_size=0.3, random_state=70)

# %%
lr = LinearRegression()
dt = DecisionTreeRegressor()

# %%
lr.fit(x_train, y_train)
dt.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
lr_pred = lr.predict(x_test)
dt_pred = dt.predict(x_test)

# %%
r2_score(y_test, lr_pred)
r2_score(y_test, dt_pred)
# Out:
# 0.7941739688051356

# %% [markdown]
# # Cross validation

# %%
lr_score = cross_val_score(lr, df, y, cv=10)
dt_score = cross_val_score(dt, df, y, cv=10)

# %%
lr_score
dt_score
# Out:
# array([ 0.51697051,  0.61186199, -1.484546  ,  0.06056769,  0.76886507,
#         0.2275603 ,  0.20139733,  0.33963421, -1.99091805,  0.10835556])

# %%
print(np.mean(lr_score))
print(np.mean(dt_score))
# Out:
# 0.22396687464126316
# -0.06402514063666186

# %% [markdown]
# # LASSO and Ridge regression

# %%
ri = Ridge()

# %%
ri.fit(x_train, y_train)
# Out:
# Ridge()

# %%
ri_pred = ri.predict(x_test)

# %%
r2_score(y_test, ri_pred)
# Out:
# 0.7418063249928931

# %%
ri_score = cross_val_score(ri, df, y, cv=10)

# %%
ri_score
# Out:
# array([ 0.73700682,  0.56385641, -0.60431388,  0.64991085,  0.5745772 ,
#         0.76284241,  0.41961646, -0.08663226, -0.65844701,  0.39104708])

# %%
np.mean(ri_score)
# Out:
# 0.27494640757298383

# %%
ls = Lasso(alpha=1e-15)

# %%
ls.fit(x_train, y_train)
# Out:
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2929.60109358799, tolerance: 2.7967875395480224
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=1e-15)

# %%
ls_pred = ls.predict(x_test)

# %%
r2_score(y_test, ls_pred)
# Out:
# 0.7435523313554935

# %%
ls_score = cross_val_score(ls, df, y, cv=10)
# Out:
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4305.279735465954, tolerance: 4.0699769802197805
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4502.927762203959, tolerance: 4.11663454945055
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4996.055371374212, tolerance: 4.123618057142857
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3019.1005488492433, tolerance: 3.34213498021978
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2676.466035415607, tolerance: 3.7586257450549456
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4808.758520867138, tolerance: 3.4413134593406594
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4795.787472424605, tolerance: 4.189029157894736
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2244.461781703682, tolerance: 3.382079664473684
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3373.802261223771, tolerance: 3.73586051754386
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4470.691195325994, tolerance: 4.100420313596492
#   model = cd_fast.enet_coordinate_descent(

# %%
np.mean(ls_score)
# Out:
# 0.22396687464126835

# %% [markdown]
# # Grid search CV

# %%
params = {'alpha':['1e-15', '1e-13', '1e-11', '1e-9', '1e-7', '1e-5', '0.0001','0.001','0.01', '0.1', '0', '1']}

# %%
a = [1e-15, 1e-13, 1e-11, 1e-9, 1e-7, 1e-5, 0.0001, 0.001,0.01, 0.1, 0, 1]
for i in range(len(a)):
    rid = Ridge(alpha= a[i])
    rid.fit(x_train, y_train)
    rid_pred = rid.predict(x_test)
    print(f'the accuracy for {a[i]} is ', r2_score(y_test, rid_pred))
# Out:
# the accuracy for 1e-15 is  0.7435523313554937
# the accuracy for 1e-13 is  0.7435523313554941
# the accuracy for 1e-11 is  0.7435523313555362
# the accuracy for 1e-09 is  0.7435523313597512
# the accuracy for 1e-07 is  0.7435523317812437
# the accuracy for 1e-05 is  0.7435523739285743
# the accuracy for 0.0001 is  0.7435527569106606
# the accuracy for 0.001 is  0.7435565693745214
# the accuracy for 0.01 is  0.7435929892291684
# the accuracy for 0.1 is  0.7438135639361431
# the accuracy for 0 is  0.7435523313554936
# the accuracy for 1 is  0.7418063249928931

# %%
grid_rid = GridSearchCV(ri, params, cv=10)

# %%
grid_rid.fit(df, y)
# Out:
# GridSearchCV(cv=10, estimator=Ridge(),
#              param_grid={'alpha': ['1e-15', '1e-13', '1e-11', '1e-9', '1e-7',
#                                    '1e-5', '0.0001', '0.001', '0.01', '0.1',
#                                    '0', '1']})

# %%
grid_rid.best_params_
# Out:
# {'alpha': '1'}

# %%
grid_las = GridSearchCV(ls, params, cv=10)

# %%
grid_las.fit(df,y)
# Out:
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
# ...
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 844, in fit
#     self.path(X, y[:, k],
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 510, in enet_path
#     l1_reg = alpha * l1_ratio * n_samples
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Sunil\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:918: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-0ebae331e0ff> in <module>
# ----> 1 grid_las.fit(df,y)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     878             refit_start_time = time.time()
#     879             if y is not None:
# --> 880                 self.best_estimator_.fit(X, y, **fit_params)
#     881             else:
#     882                 self.best_estimator_.fit(X, **fit_params)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py in fit(self, X, y, sample_weight, check_input)
#     842                 this_Xy = None
#     843             _, this_coef, this_dual_gap, this_iter = \
# --> 844                 self.path(X, y[:, k],
#     845                           l1_ratio=self.l1_ratio, eps=None,
#     846                           n_alphas=None, alphas=[alpha],
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py in enet_path(X, y, l1_ratio, eps, n_alphas, alphas, precompute, Xy, copy_X, coef_init, verbose, return_n_iter, positive, check_input, **params)
#     508
#     509     for i, alpha in enumerate(alphas):
# --> 510         l1_reg = alpha * l1_ratio * n_samples
#     511         l2_reg = alpha * (1.0 - l1_ratio) * n_samples
#     512         if not multi_output and sparse.isspmatrix(X):
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
grid_las.best_params_
# Out:
# {'alpha': '1e-15'}
